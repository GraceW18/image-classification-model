# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceW18/image-classification-model-CNN/blob/main/CNNmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
from collections import defaultdict

# Load and reshape data
train_data = pd.read_csv('sign_mnist_13bal_train.csv')
test_data = pd.read_csv('sign_mnist_13bal_test.csv')
X_train = train_data.drop('class', axis=1).values / 255.0
y_train = train_data['class'].values
X_test = test_data.drop('class', axis=1).values / 255.0
y_test = test_data['class'].values

# Clean label values (remove/mapping for invalid ones if needed)
y_train[y_train == 10] = 9
y_test[y_test == 10] = 9

# Reshape features from flat to 28x28x1 for images
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)
num_classes = 10

datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.05,
    zoom_range=0.08,
    horizontal_flip=False,
    vertical_flip=False
)
datagen.fit(X_train)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,
                              patience=3, min_lr=1e-5, verbose=1)

# Early stopping for generalization
early_stop = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# Build improved CNN model
model = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])
model.compile(optimizer=Adam(learning_rate=0.005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Generate augmented data batches and fit the model
model.fit(datagen.flow(X_train, y_train, batch_size=16), epochs=150,
          validation_data=(X_test, y_test), callbacks=[reduce_lr, early_stop], verbose=2)

# Get predictions for training and test sets
y_pred_train = np.argmax(model.predict(X_train), axis=1)
y_pred = np.argmax(model.predict(X_test), axis=1)

# Print network summary and architecture layers
print(f"Training set size: {len(y_train)}")
print(f"Layer sizes: Conv2D(32)->Conv2D(64)->Dense(128)->Dense({num_classes})")

# Per-class and overall accuracy calculations
correct_counts = defaultdict(int)
total_counts = defaultdict(int)
overall_correct = 0
for true, pred in zip(y_test, y_pred):
    total_counts[true] += 1
    if true == pred:
        correct_counts[true] += 1
        overall_correct += 1

total_counts_training = 0
correct_counts_training = 0
for true, pred in zip(y_train, y_pred_train):
    total_counts_training += 1
    if true == pred:
        correct_counts_training += 1

for class_id in sorted(total_counts.keys()):
    accuracy = correct_counts[class_id] / total_counts[class_id] * 100
    print(f"Accuracy for class {class_id}: {accuracy:3.0f}%")
print("----------")
overall_accuracy = overall_correct / len(y_test) * 100
print(f"Overall Test Accuracy: {overall_accuracy:3.1f}%")
overall_training_accuracy = correct_counts_training / total_counts_training * 100
print(f"Overall Training Accuracy: {overall_training_accuracy:3.1f}%")

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
for i, row in enumerate(conf_matrix):
    print(f"Class {i}:", " ".join(f"{num:5d}" for num in row))
# Out:
# Epoch 1/150
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 - 5s - 505ms/step - accuracy: 0.1462 - loss: 5.0435 - val_accuracy: 0.0923 - val_loss: 2.5133 - learning_rate: 0.0050
# Epoch 2/150
# 9/9 - 1s - 57ms/step - accuracy: 0.4077 - loss: 3.1784 - val_accuracy: 0.1077 - val_loss: 4.4185 - learning_rate: 0.0050
# Epoch 3/150
# 9/9 - 1s - 62ms/step - accuracy: 0.5077 - loss: 2.3279 - val_accuracy: 0.1462 - val_loss: 2.8140 - learning_rate: 0.0050
# Epoch 4/150
# 9/9 - 1s - 63ms/step - accuracy: 0.5308 - loss: 2.0158 - val_accuracy: 0.2077 - val_loss: 3.0833 - learning_rate: 0.0050
# Epoch 5/150
# 9/9 - 1s - 63ms/step - accuracy: 0.5538 - loss: 1.8829 - val_accuracy: 0.2385 - val_loss: 2.4543 - learning_rate: 0.0050
# Epoch 6/150
# 9/9 - 1s - 60ms/step - accuracy: 0.6462 - loss: 1.7362 - val_accuracy: 0.1846 - val_loss: 3.3106 - learning_rate: 0.0050
# Epoch 7/150
# 9/9 - 1s - 70ms/step - accuracy: 0.6385 - loss: 1.5088 - val_accuracy: 0.2769 - val_loss: 2.8391 - learning_rate: 0.0050
# Epoch 8/150
# 9/9 - 1s - 62ms/step - accuracy: 0.6385 - loss: 1.3727 - val_accuracy: 0.1538 - val_loss: 4.1466 - learning_rate: 0.0050
# Epoch 9/150
# 9/9 - 1s - 61ms/step - accuracy: 0.8000 - loss: 0.7663 - val_accuracy: 0.1769 - val_loss: 3.7409 - learning_rate: 0.0050
# Epoch 10/150
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 9/9 - 1s - 65ms/step - accuracy: 0.8154 - loss: 0.7718 - val_accuracy: 0.1692 - val_loss: 4.9316 - learning_rate: 0.0050
# Epoch 11/150
# 9/9 - 1s - 63ms/step - accuracy: 0.7615 - loss: 0.8706 - val_accuracy: 0.1462 - val_loss: 5.6681 - learning_rate: 0.0025
# Epoch 12/150
# 9/9 - 1s - 114ms/step - accuracy: 0.8000 - loss: 0.7256 - val_accuracy: 0.2231 - val_loss: 5.0218 - learning_rate: 0.0025
# Epoch 13/150
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 9/9 - 1s - 146ms/step - accuracy: 0.9154 - loss: 0.2668 - val_accuracy: 0.2000 - val_loss: 4.6306 - learning_rate: 0.0025
# Epoch 14/150
# 9/9 - 1s - 89ms/step - accuracy: 0.8615 - loss: 0.5372 - val_accuracy: 0.1154 - val_loss: 4.7852 - learning_rate: 0.0012
# Epoch 15/150
# 9/9 - 1s - 56ms/step - accuracy: 0.8846 - loss: 0.4138 - val_accuracy: 0.1231 - val_loss: 5.3217 - learning_rate: 0.0012
# Epoch 16/150
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 9/9 - 1s - 58ms/step - accuracy: 0.9000 - loss: 0.2728 - val_accuracy: 0.1231 - val_loss: 5.8257 - learning_rate: 0.0012
# Epoch 17/150
# 9/9 - 1s - 72ms/step - accuracy: 0.8846 - loss: 0.4013 - val_accuracy: 0.1231 - val_loss: 6.2841 - learning_rate: 6.2500e-04
# Epoch 18/150
# 9/9 - 1s - 58ms/step - accuracy: 0.8769 - loss: 0.3345 - val_accuracy: 0.1154 - val_loss: 6.9002 - learning_rate: 6.2500e-04
# Epoch 19/150
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 9/9 - 1s - 61ms/step - accuracy: 0.9154 - loss: 0.2779 - val_accuracy: 0.1154 - val_loss: 7.2290 - learning_rate: 6.2500e-04
# Epoch 20/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9692 - loss: 0.1313 - val_accuracy: 0.1154 - val_loss: 7.3702 - learning_rate: 3.1250e-04
# Epoch 21/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9000 - loss: 0.2988 - val_accuracy: 0.1154 - val_loss: 7.4794 - learning_rate: 3.1250e-04
# Epoch 22/150
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 9/9 - 1s - 58ms/step - accuracy: 0.9231 - loss: 0.2749 - val_accuracy: 0.1154 - val_loss: 7.5147 - learning_rate: 3.1250e-04
# Epoch 23/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9462 - loss: 0.1570 - val_accuracy: 0.1231 - val_loss: 7.4621 - learning_rate: 1.5625e-04
# Epoch 24/150
# 9/9 - 1s - 63ms/step - accuracy: 0.8846 - loss: 0.3140 - val_accuracy: 0.1231 - val_loss: 7.3390 - learning_rate: 1.5625e-04
# Epoch 25/150
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 9/9 - 1s - 56ms/step - accuracy: 0.9154 - loss: 0.2281 - val_accuracy: 0.1231 - val_loss: 7.1918 - learning_rate: 1.5625e-04
# Epoch 26/150
# 9/9 - 1s - 68ms/step - accuracy: 0.9385 - loss: 0.1973 - val_accuracy: 0.1308 - val_loss: 7.0285 - learning_rate: 7.8125e-05
# Epoch 27/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9462 - loss: 0.1576 - val_accuracy: 0.1308 - val_loss: 6.7927 - learning_rate: 7.8125e-05
# Epoch 28/150
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 9/9 - 1s - 56ms/step - accuracy: 0.9154 - loss: 0.2539 - val_accuracy: 0.1308 - val_loss: 6.5808 - learning_rate: 7.8125e-05
# Epoch 29/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9462 - loss: 0.1744 - val_accuracy: 0.1308 - val_loss: 6.3212 - learning_rate: 3.9062e-05
# Epoch 30/150
# 9/9 - 0s - 55ms/step - accuracy: 0.8923 - loss: 0.3258 - val_accuracy: 0.1462 - val_loss: 6.0166 - learning_rate: 3.9062e-05
# Epoch 31/150
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 9/9 - 1s - 63ms/step - accuracy: 0.9154 - loss: 0.2235 - val_accuracy: 0.1615 - val_loss: 5.6677 - learning_rate: 3.9062e-05
# Epoch 32/150
# 9/9 - 1s - 113ms/step - accuracy: 0.9462 - loss: 0.1189 - val_accuracy: 0.1769 - val_loss: 5.3740 - learning_rate: 1.9531e-05
# Epoch 33/150
# 9/9 - 1s - 144ms/step - accuracy: 0.9385 - loss: 0.1466 - val_accuracy: 0.1846 - val_loss: 5.0238 - learning_rate: 1.9531e-05
# Epoch 34/150
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-05.
# 9/9 - 1s - 63ms/step - accuracy: 0.9308 - loss: 0.2132 - val_accuracy: 0.2000 - val_loss: 4.6455 - learning_rate: 1.9531e-05
# Epoch 35/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9692 - loss: 0.1037 - val_accuracy: 0.2538 - val_loss: 4.3006 - learning_rate: 1.0000e-05
# Epoch 36/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9308 - loss: 0.1498 - val_accuracy: 0.2923 - val_loss: 3.9544 - learning_rate: 1.0000e-05
# Epoch 37/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9462 - loss: 0.2733 - val_accuracy: 0.3154 - val_loss: 3.6471 - learning_rate: 1.0000e-05
# Epoch 38/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9231 - loss: 0.2113 - val_accuracy: 0.3231 - val_loss: 3.3299 - learning_rate: 1.0000e-05
# Epoch 39/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9231 - loss: 0.1866 - val_accuracy: 0.3538 - val_loss: 3.0073 - learning_rate: 1.0000e-05
# Epoch 40/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9077 - loss: 0.2436 - val_accuracy: 0.3846 - val_loss: 2.7291 - learning_rate: 1.0000e-05
# Epoch 41/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9385 - loss: 0.2043 - val_accuracy: 0.4231 - val_loss: 2.4789 - learning_rate: 1.0000e-05
# Epoch 42/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9385 - loss: 0.1909 - val_accuracy: 0.4923 - val_loss: 2.2253 - learning_rate: 1.0000e-05
# Epoch 43/150
# 9/9 - 1s - 74ms/step - accuracy: 0.9308 - loss: 0.2419 - val_accuracy: 0.5154 - val_loss: 1.9929 - learning_rate: 1.0000e-05
# Epoch 44/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9077 - loss: 0.2205 - val_accuracy: 0.5538 - val_loss: 1.7687 - learning_rate: 1.0000e-05
# Epoch 45/150
# 9/9 - 1s - 62ms/step - accuracy: 0.8923 - loss: 0.2963 - val_accuracy: 0.5846 - val_loss: 1.5787 - learning_rate: 1.0000e-05
# Epoch 46/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9231 - loss: 0.2140 - val_accuracy: 0.6231 - val_loss: 1.4051 - learning_rate: 1.0000e-05
# Epoch 47/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9231 - loss: 0.1746 - val_accuracy: 0.6462 - val_loss: 1.2370 - learning_rate: 1.0000e-05
# Epoch 48/150
# 9/9 - 1s - 64ms/step - accuracy: 0.8692 - loss: 0.3084 - val_accuracy: 0.6692 - val_loss: 1.0925 - learning_rate: 1.0000e-05
# Epoch 49/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9231 - loss: 0.2218 - val_accuracy: 0.6692 - val_loss: 0.9608 - learning_rate: 1.0000e-05
# Epoch 50/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9000 - loss: 0.2272 - val_accuracy: 0.7000 - val_loss: 0.8340 - learning_rate: 1.0000e-05
# Epoch 51/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9077 - loss: 0.2338 - val_accuracy: 0.7154 - val_loss: 0.7292 - learning_rate: 1.0000e-05
# Epoch 52/150
# 9/9 - 1s - 110ms/step - accuracy: 0.9692 - loss: 0.1169 - val_accuracy: 0.7308 - val_loss: 0.6381 - learning_rate: 1.0000e-05
# Epoch 53/150
# 9/9 - 1s - 125ms/step - accuracy: 0.9231 - loss: 0.1779 - val_accuracy: 0.7615 - val_loss: 0.5665 - learning_rate: 1.0000e-05
# Epoch 54/150
# 9/9 - 1s - 106ms/step - accuracy: 0.9154 - loss: 0.1935 - val_accuracy: 0.7923 - val_loss: 0.5072 - learning_rate: 1.0000e-05
# Epoch 55/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9538 - loss: 0.1926 - val_accuracy: 0.8154 - val_loss: 0.4559 - learning_rate: 1.0000e-05
# Epoch 56/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9308 - loss: 0.2070 - val_accuracy: 0.8231 - val_loss: 0.4122 - learning_rate: 1.0000e-05
# Epoch 57/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9385 - loss: 0.2496 - val_accuracy: 0.8538 - val_loss: 0.3789 - learning_rate: 1.0000e-05
# Epoch 58/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9154 - loss: 0.2179 - val_accuracy: 0.8769 - val_loss: 0.3511 - learning_rate: 1.0000e-05
# Epoch 59/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9077 - loss: 0.1992 - val_accuracy: 0.8769 - val_loss: 0.3303 - learning_rate: 1.0000e-05
# Epoch 60/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9385 - loss: 0.2183 - val_accuracy: 0.8923 - val_loss: 0.3125 - learning_rate: 1.0000e-05
# Epoch 61/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9308 - loss: 0.2289 - val_accuracy: 0.9000 - val_loss: 0.2982 - learning_rate: 1.0000e-05
# Epoch 62/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9692 - loss: 0.1605 - val_accuracy: 0.9000 - val_loss: 0.2884 - learning_rate: 1.0000e-05
# Epoch 63/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9308 - loss: 0.1902 - val_accuracy: 0.9000 - val_loss: 0.2808 - learning_rate: 1.0000e-05
# Epoch 64/150
# 9/9 - 1s - 72ms/step - accuracy: 0.9308 - loss: 0.1993 - val_accuracy: 0.9077 - val_loss: 0.2744 - learning_rate: 1.0000e-05
# Epoch 65/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9308 - loss: 0.2888 - val_accuracy: 0.9077 - val_loss: 0.2698 - learning_rate: 1.0000e-05
# Epoch 66/150
# 9/9 - 1s - 65ms/step - accuracy: 0.9308 - loss: 0.1932 - val_accuracy: 0.9077 - val_loss: 0.2662 - learning_rate: 1.0000e-05
# Epoch 67/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9385 - loss: 0.1771 - val_accuracy: 0.9077 - val_loss: 0.2637 - learning_rate: 1.0000e-05
# Epoch 68/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9538 - loss: 0.1785 - val_accuracy: 0.9077 - val_loss: 0.2615 - learning_rate: 1.0000e-05
# Epoch 69/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9231 - loss: 0.1997 - val_accuracy: 0.9000 - val_loss: 0.2600 - learning_rate: 1.0000e-05
# Epoch 70/150
# 9/9 - 1s - 72ms/step - accuracy: 0.9308 - loss: 0.2200 - val_accuracy: 0.9000 - val_loss: 0.2603 - learning_rate: 1.0000e-05
# Epoch 71/150
# 9/9 - 1s - 96ms/step - accuracy: 0.9308 - loss: 0.2524 - val_accuracy: 0.9000 - val_loss: 0.2611 - learning_rate: 1.0000e-05
# Epoch 72/150
# 9/9 - 1s - 137ms/step - accuracy: 0.9154 - loss: 0.2198 - val_accuracy: 0.9000 - val_loss: 0.2618 - learning_rate: 1.0000e-05
# Epoch 73/150
# 9/9 - 1s - 109ms/step - accuracy: 0.9462 - loss: 0.2095 - val_accuracy: 0.9077 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 74/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9462 - loss: 0.2257 - val_accuracy: 0.8923 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 75/150
# 9/9 - 1s - 62ms/step - accuracy: 0.8923 - loss: 0.2454 - val_accuracy: 0.9000 - val_loss: 0.2644 - learning_rate: 1.0000e-05
# Epoch 76/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9538 - loss: 0.1201 - val_accuracy: 0.9000 - val_loss: 0.2650 - learning_rate: 1.0000e-05
# Epoch 77/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9385 - loss: 0.2888 - val_accuracy: 0.9000 - val_loss: 0.2664 - learning_rate: 1.0000e-05
# Epoch 78/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9231 - loss: 0.2114 - val_accuracy: 0.9000 - val_loss: 0.2680 - learning_rate: 1.0000e-05
# Epoch 79/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9231 - loss: 0.1775 - val_accuracy: 0.9000 - val_loss: 0.2695 - learning_rate: 1.0000e-05
# Epoch 80/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9077 - loss: 0.2769 - val_accuracy: 0.9077 - val_loss: 0.2712 - learning_rate: 1.0000e-05
# Epoch 81/150
# 9/9 - 1s - 57ms/step - accuracy: 0.8846 - loss: 0.2615 - val_accuracy: 0.9000 - val_loss: 0.2722 - learning_rate: 1.0000e-05
# Epoch 82/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9231 - loss: 0.1651 - val_accuracy: 0.9077 - val_loss: 0.2728 - learning_rate: 1.0000e-05
# Epoch 83/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9231 - loss: 0.1995 - val_accuracy: 0.9077 - val_loss: 0.2724 - learning_rate: 1.0000e-05
# Epoch 84/150
# 9/9 - 1s - 71ms/step - accuracy: 0.9385 - loss: 0.1991 - val_accuracy: 0.9077 - val_loss: 0.2724 - learning_rate: 1.0000e-05
# Epoch 85/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9308 - loss: 0.1523 - val_accuracy: 0.9077 - val_loss: 0.2731 - learning_rate: 1.0000e-05
# Epoch 86/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9077 - loss: 0.2421 - val_accuracy: 0.9077 - val_loss: 0.2731 - learning_rate: 1.0000e-05
# Epoch 87/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9000 - loss: 0.2306 - val_accuracy: 0.9077 - val_loss: 0.2736 - learning_rate: 1.0000e-05
# Epoch 88/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9077 - loss: 0.1617 - val_accuracy: 0.9077 - val_loss: 0.2738 - learning_rate: 1.0000e-05
# Epoch 89/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9692 - loss: 0.1217 - val_accuracy: 0.9077 - val_loss: 0.2741 - learning_rate: 1.0000e-05
# Epoch 90/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9231 - loss: 0.2021 - val_accuracy: 0.9077 - val_loss: 0.2750 - learning_rate: 1.0000e-05
# Epoch 91/150
# 9/9 - 1s - 108ms/step - accuracy: 0.9769 - loss: 0.1127 - val_accuracy: 0.9077 - val_loss: 0.2751 - learning_rate: 1.0000e-05
# Epoch 92/150
# 9/9 - 1s - 95ms/step - accuracy: 0.9462 - loss: 0.2493 - val_accuracy: 0.9077 - val_loss: 0.2750 - learning_rate: 1.0000e-05
# Epoch 93/150
# 9/9 - 1s - 103ms/step - accuracy: 0.9231 - loss: 0.2347 - val_accuracy: 0.9077 - val_loss: 0.2764 - learning_rate: 1.0000e-05
# Epoch 94/150
# 9/9 - 1s - 72ms/step - accuracy: 0.9385 - loss: 0.1909 - val_accuracy: 0.9077 - val_loss: 0.2763 - learning_rate: 1.0000e-05
# Epoch 95/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9462 - loss: 0.1489 - val_accuracy: 0.9077 - val_loss: 0.2758 - learning_rate: 1.0000e-05
# Epoch 96/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9308 - loss: 0.2049 - val_accuracy: 0.9077 - val_loss: 0.2761 - learning_rate: 1.0000e-05
# Epoch 97/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9538 - loss: 0.1464 - val_accuracy: 0.9077 - val_loss: 0.2762 - learning_rate: 1.0000e-05
# Epoch 98/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9462 - loss: 0.1460 - val_accuracy: 0.9077 - val_loss: 0.2754 - learning_rate: 1.0000e-05
# Epoch 99/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9385 - loss: 0.2121 - val_accuracy: 0.9077 - val_loss: 0.2759 - learning_rate: 1.0000e-05
# Epoch 100/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9769 - loss: 0.1196 - val_accuracy: 0.9077 - val_loss: 0.2765 - learning_rate: 1.0000e-05
# Epoch 101/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9538 - loss: 0.1488 - val_accuracy: 0.9077 - val_loss: 0.2767 - learning_rate: 1.0000e-05
# Epoch 102/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9000 - loss: 0.2408 - val_accuracy: 0.9077 - val_loss: 0.2773 - learning_rate: 1.0000e-05
# Epoch 103/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9462 - loss: 0.1451 - val_accuracy: 0.9077 - val_loss: 0.2771 - learning_rate: 1.0000e-05
# Epoch 104/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9231 - loss: 0.1857 - val_accuracy: 0.9077 - val_loss: 0.2774 - learning_rate: 1.0000e-05
# Epoch 105/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9154 - loss: 0.2084 - val_accuracy: 0.9077 - val_loss: 0.2781 - learning_rate: 1.0000e-05
# Epoch 106/150
# 9/9 - 1s - 65ms/step - accuracy: 0.9385 - loss: 0.1945 - val_accuracy: 0.9077 - val_loss: 0.2778 - learning_rate: 1.0000e-05
# Epoch 107/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9308 - loss: 0.1912 - val_accuracy: 0.9077 - val_loss: 0.2770 - learning_rate: 1.0000e-05
# Epoch 108/150
# 9/9 - 1s - 65ms/step - accuracy: 0.9462 - loss: 0.2297 - val_accuracy: 0.9077 - val_loss: 0.2761 - learning_rate: 1.0000e-05
# Epoch 109/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9385 - loss: 0.2131 - val_accuracy: 0.9077 - val_loss: 0.2758 - learning_rate: 1.0000e-05
# Epoch 110/150
# 9/9 - 1s - 66ms/step - accuracy: 0.9538 - loss: 0.1585 - val_accuracy: 0.9077 - val_loss: 0.2766 - learning_rate: 1.0000e-05
# Epoch 111/150
# 9/9 - 1s - 115ms/step - accuracy: 0.9462 - loss: 0.1679 - val_accuracy: 0.9077 - val_loss: 0.2761 - learning_rate: 1.0000e-05
# Epoch 112/150
# 9/9 - 1s - 113ms/step - accuracy: 0.9000 - loss: 0.2536 - val_accuracy: 0.9077 - val_loss: 0.2761 - learning_rate: 1.0000e-05
# Epoch 113/150
# 9/9 - 1s - 78ms/step - accuracy: 0.9231 - loss: 0.1931 - val_accuracy: 0.9077 - val_loss: 0.2757 - learning_rate: 1.0000e-05
# Epoch 114/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9154 - loss: 0.2459 - val_accuracy: 0.9077 - val_loss: 0.2770 - learning_rate: 1.0000e-05
# Epoch 115/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9231 - loss: 0.1626 - val_accuracy: 0.9077 - val_loss: 0.2777 - learning_rate: 1.0000e-05
# Epoch 116/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9154 - loss: 0.2424 - val_accuracy: 0.9077 - val_loss: 0.2779 - learning_rate: 1.0000e-05
# Epoch 117/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9538 - loss: 0.1920 - val_accuracy: 0.9077 - val_loss: 0.2786 - learning_rate: 1.0000e-05
# Epoch 118/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9462 - loss: 0.2003 - val_accuracy: 0.9077 - val_loss: 0.2790 - learning_rate: 1.0000e-05
# Epoch 119/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9615 - loss: 0.0994 - val_accuracy: 0.9077 - val_loss: 0.2793 - learning_rate: 1.0000e-05
# Epoch 120/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9231 - loss: 0.2414 - val_accuracy: 0.9077 - val_loss: 0.2793 - learning_rate: 1.0000e-05
# Epoch 121/150
# 9/9 - 1s - 73ms/step - accuracy: 0.9308 - loss: 0.1625 - val_accuracy: 0.9077 - val_loss: 0.2799 - learning_rate: 1.0000e-05
# Epoch 122/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9615 - loss: 0.1583 - val_accuracy: 0.9077 - val_loss: 0.2796 - learning_rate: 1.0000e-05
# Epoch 123/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9538 - loss: 0.1519 - val_accuracy: 0.9077 - val_loss: 0.2797 - learning_rate: 1.0000e-05
# Epoch 124/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9615 - loss: 0.1277 - val_accuracy: 0.9077 - val_loss: 0.2795 - learning_rate: 1.0000e-05
# Epoch 125/150
# 9/9 - 1s - 66ms/step - accuracy: 0.9462 - loss: 0.1558 - val_accuracy: 0.9077 - val_loss: 0.2800 - learning_rate: 1.0000e-05
# Epoch 126/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9692 - loss: 0.1180 - val_accuracy: 0.9077 - val_loss: 0.2808 - learning_rate: 1.0000e-05
# Epoch 127/150
# 9/9 - 1s - 58ms/step - accuracy: 0.9231 - loss: 0.3339 - val_accuracy: 0.9077 - val_loss: 0.2802 - learning_rate: 1.0000e-05
# Epoch 128/150
# 9/9 - 1s - 68ms/step - accuracy: 0.9308 - loss: 0.1923 - val_accuracy: 0.9077 - val_loss: 0.2805 - learning_rate: 1.0000e-05
# Epoch 129/150
# 9/9 - 1s - 74ms/step - accuracy: 0.9846 - loss: 0.1557 - val_accuracy: 0.9077 - val_loss: 0.2796 - learning_rate: 1.0000e-05
# Epoch 130/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9385 - loss: 0.1988 - val_accuracy: 0.9077 - val_loss: 0.2796 - learning_rate: 1.0000e-05
# Epoch 131/150
# 9/9 - 1s - 95ms/step - accuracy: 0.9308 - loss: 0.2047 - val_accuracy: 0.9077 - val_loss: 0.2800 - learning_rate: 1.0000e-05
# Epoch 132/150
# 9/9 - 1s - 144ms/step - accuracy: 0.9538 - loss: 0.1719 - val_accuracy: 0.9077 - val_loss: 0.2790 - learning_rate: 1.0000e-05
# Epoch 133/150
# 9/9 - 1s - 103ms/step - accuracy: 0.9538 - loss: 0.1686 - val_accuracy: 0.9077 - val_loss: 0.2793 - learning_rate: 1.0000e-05
# Epoch 134/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9077 - loss: 0.2599 - val_accuracy: 0.9077 - val_loss: 0.2795 - learning_rate: 1.0000e-05
# Epoch 135/150
# 9/9 - 1s - 71ms/step - accuracy: 0.9385 - loss: 0.1311 - val_accuracy: 0.9077 - val_loss: 0.2790 - learning_rate: 1.0000e-05
# Epoch 136/150
# 9/9 - 1s - 62ms/step - accuracy: 0.8769 - loss: 0.2966 - val_accuracy: 0.9077 - val_loss: 0.2791 - learning_rate: 1.0000e-05
# Epoch 137/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9308 - loss: 0.2046 - val_accuracy: 0.9077 - val_loss: 0.2792 - learning_rate: 1.0000e-05
# Epoch 138/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9154 - loss: 0.2347 - val_accuracy: 0.9077 - val_loss: 0.2790 - learning_rate: 1.0000e-05
# Epoch 139/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9462 - loss: 0.1362 - val_accuracy: 0.9077 - val_loss: 0.2797 - learning_rate: 1.0000e-05
# Epoch 140/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9538 - loss: 0.1238 - val_accuracy: 0.9077 - val_loss: 0.2794 - learning_rate: 1.0000e-05
# Epoch 141/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9231 - loss: 0.2130 - val_accuracy: 0.9077 - val_loss: 0.2788 - learning_rate: 1.0000e-05
# Epoch 142/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9538 - loss: 0.1614 - val_accuracy: 0.9077 - val_loss: 0.2793 - learning_rate: 1.0000e-05
# Epoch 143/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9385 - loss: 0.1782 - val_accuracy: 0.9077 - val_loss: 0.2787 - learning_rate: 1.0000e-05
# Epoch 144/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9308 - loss: 0.1851 - val_accuracy: 0.9077 - val_loss: 0.2791 - learning_rate: 1.0000e-05
# Epoch 145/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9231 - loss: 0.3117 - val_accuracy: 0.9077 - val_loss: 0.2793 - learning_rate: 1.0000e-05
# Epoch 146/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9231 - loss: 0.2120 - val_accuracy: 0.9077 - val_loss: 0.2781 - learning_rate: 1.0000e-05
# Epoch 147/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9462 - loss: 0.1664 - val_accuracy: 0.9077 - val_loss: 0.2779 - learning_rate: 1.0000e-05
# Epoch 148/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9462 - loss: 0.1897 - val_accuracy: 0.9077 - val_loss: 0.2771 - learning_rate: 1.0000e-05
# Epoch 149/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9538 - loss: 0.1936 - val_accuracy: 0.9077 - val_loss: 0.2766 - learning_rate: 1.0000e-05
# Epoch 150/150
# 9/9 - 1s - 85ms/step - accuracy: 0.9462 - loss: 0.1947 - val_accuracy: 0.9077 - val_loss: 0.2756 - learning_rate: 1.0000e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Training set size: 130
# Layer sizes: Conv2D(32)->Conv2D(64)->Dense(128)->Dense(10)
# Accuracy for class 0:  92%
# Accuracy for class 1:  85%
# Accuracy for class 2: 100%
# Accuracy for class 3:  77%
# Accuracy for class 4:  92%
# Accuracy for class 5: 100%
# Accuracy for class 6:  85%
# Accuracy for class 7:  85%
# Accuracy for class 8:  92%
# Accuracy for class 9:  92%
# ----------
# Overall Test Accuracy: 90.0%
# Overall Training Accuracy: 100.0%
# Confusion Matrix:
# Class 0:    12     0     0     0     0     0     0     0     1     0
# Class 1:     0    11     0     0     0     0     0     0     1     1
# Class 2:     0     0    13     0     0     0     0     0     0     0
# Class 3:     0     0     0    10     0     2     0     1     0     0
# Class 4:     0     0     0     1    12     0     0     0     0     0
# Class 5:     0     0     0     0     0    13     0     0     0     0
# Class 6:     0     0     0     0     0     0    11     2     0     0
# Class 7:     0     0     0     0     0     0     2    11     0     0
# Class 8:     0     0     0     0     0     0     0     0    12     1
# Class 9:     0     1     0     0     0     0     0     0     0    12
