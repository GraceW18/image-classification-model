# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceW18/image-classification-model-CNN/blob/main/CNNmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
from collections import defaultdict

# Load and reshape data
train_data = pd.read_csv('sign_mnist_13bal_train.csv')
test_data = pd.read_csv('sign_mnist_13bal_test.csv')
X_train = train_data.drop('class', axis=1).values / 255.0
y_train = train_data['class'].values
X_test = test_data.drop('class', axis=1).values / 255.0
y_test = test_data['class'].values

# Clean label values (remove/mapping for invalid ones if needed)
y_train[y_train == 10] = 9
y_test[y_test == 10] = 9

# Reshape features from flat to 28x28x1 for images
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)
num_classes = 10

datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.05,
    zoom_range=0.08,
    horizontal_flip=False,
    vertical_flip=False
)
datagen.fit(X_train)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,
                              patience=5, min_lr=1e-6, verbose=1)

# Early stopping for generalization
early_stop = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# Build improved CNN model
model = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])
model.compile(optimizer=Adam(learning_rate=0.005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Generate augmented data batches and fit the model
model.fit(datagen.flow(X_train, y_train, batch_size=16), epochs=150,
          validation_data=(X_test, y_test), callbacks=[reduce_lr, early_stop], verbose=2)

# Get predictions for training and test sets
y_pred_train = np.argmax(model.predict(X_train), axis=1)
y_pred = np.argmax(model.predict(X_test), axis=1)

# Print network summary and architecture layers
print(f"Training set size: {len(y_train)}")
print(f"Layer sizes: Conv2D(32)->Conv2D(64)->Dense(128)->Dense({num_classes})")

# Per-class and overall accuracy calculations
correct_counts = defaultdict(int)
total_counts = defaultdict(int)
overall_correct = 0
for true, pred in zip(y_test, y_pred):
    total_counts[true] += 1
    if true == pred:
        correct_counts[true] += 1
        overall_correct += 1

total_counts_training = 0
correct_counts_training = 0
for true, pred in zip(y_train, y_pred_train):
    total_counts_training += 1
    if true == pred:
        correct_counts_training += 1

for class_id in sorted(total_counts.keys()):
    accuracy = correct_counts[class_id] / total_counts[class_id] * 100
    print(f"Accuracy for class {class_id}: {accuracy:3.0f}%")
print("----------")
overall_accuracy = overall_correct / len(y_test) * 100
print(f"Overall Test Accuracy: {overall_accuracy:3.1f}%")
overall_training_accuracy = correct_counts_training / total_counts_training * 100
print(f"Overall Training Accuracy: {overall_training_accuracy:3.1f}%")

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
for i, row in enumerate(conf_matrix):
    print(f"Class {i}:", " ".join(f"{num:5d}" for num in row))
# Out:
# Epoch 1/150
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 - 6s - 627ms/step - accuracy: 0.1769 - loss: 2.7973 - val_accuracy: 0.1154 - val_loss: 2.3424 - learning_rate: 0.0050
# Epoch 2/150
# 9/9 - 1s - 57ms/step - accuracy: 0.3385 - loss: 1.9369 - val_accuracy: 0.1385 - val_loss: 2.3097 - learning_rate: 0.0050
# Epoch 3/150
# 9/9 - 1s - 57ms/step - accuracy: 0.5692 - loss: 1.2284 - val_accuracy: 0.1000 - val_loss: 2.6253 - learning_rate: 0.0050
# Epoch 4/150
# 9/9 - 0s - 55ms/step - accuracy: 0.5923 - loss: 1.2935 - val_accuracy: 0.1231 - val_loss: 2.7066 - learning_rate: 0.0050
# Epoch 5/150
# 9/9 - 1s - 64ms/step - accuracy: 0.6692 - loss: 1.1089 - val_accuracy: 0.2231 - val_loss: 2.6625 - learning_rate: 0.0050
# Epoch 6/150
# 9/9 - 1s - 60ms/step - accuracy: 0.6692 - loss: 1.0139 - val_accuracy: 0.2154 - val_loss: 2.6777 - learning_rate: 0.0050
# Epoch 7/150
# 9/9 - 1s - 62ms/step - accuracy: 0.7000 - loss: 0.8100 - val_accuracy: 0.2385 - val_loss: 3.1003 - learning_rate: 0.0050
# Epoch 8/150
# 9/9 - 1s - 60ms/step - accuracy: 0.7846 - loss: 0.7331 - val_accuracy: 0.2077 - val_loss: 2.7806 - learning_rate: 0.0050
# Epoch 9/150
# 9/9 - 1s - 63ms/step - accuracy: 0.7692 - loss: 0.8575 - val_accuracy: 0.1846 - val_loss: 3.2114 - learning_rate: 0.0050
# Epoch 10/150
# 9/9 - 1s - 60ms/step - accuracy: 0.7846 - loss: 0.6840 - val_accuracy: 0.2615 - val_loss: 2.5068 - learning_rate: 0.0050
# Epoch 11/150
# 9/9 - 1s - 58ms/step - accuracy: 0.8154 - loss: 0.5882 - val_accuracy: 0.2692 - val_loss: 2.5870 - learning_rate: 0.0050
# Epoch 12/150
# 9/9 - 1s - 72ms/step - accuracy: 0.8231 - loss: 0.5114 - val_accuracy: 0.1846 - val_loss: 3.8979 - learning_rate: 0.0050
# Epoch 13/150
# 9/9 - 1s - 68ms/step - accuracy: 0.8308 - loss: 0.4584 - val_accuracy: 0.2000 - val_loss: 4.0711 - learning_rate: 0.0050
# Epoch 14/150
# 9/9 - 1s - 61ms/step - accuracy: 0.7923 - loss: 0.6355 - val_accuracy: 0.2692 - val_loss: 3.2518 - learning_rate: 0.0050
# Epoch 15/150
# 9/9 - 1s - 60ms/step - accuracy: 0.7846 - loss: 0.8247 - val_accuracy: 0.2692 - val_loss: 3.5687 - learning_rate: 0.0050
# Epoch 16/150
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 9/9 - 1s - 57ms/step - accuracy: 0.7846 - loss: 0.5726 - val_accuracy: 0.2692 - val_loss: 2.7152 - learning_rate: 0.0050
# Epoch 17/150
# 9/9 - 1s - 67ms/step - accuracy: 0.8385 - loss: 0.4472 - val_accuracy: 0.3077 - val_loss: 2.3175 - learning_rate: 0.0025
# Epoch 18/150
# 9/9 - 1s - 107ms/step - accuracy: 0.8231 - loss: 0.5281 - val_accuracy: 0.3615 - val_loss: 2.5968 - learning_rate: 0.0025
# Epoch 19/150
# 9/9 - 1s - 124ms/step - accuracy: 0.8538 - loss: 0.3998 - val_accuracy: 0.3462 - val_loss: 2.5872 - learning_rate: 0.0025
# Epoch 20/150
# 9/9 - 0s - 55ms/step - accuracy: 0.8846 - loss: 0.3682 - val_accuracy: 0.1154 - val_loss: 4.6067 - learning_rate: 0.0025
# Epoch 21/150
# 9/9 - 1s - 73ms/step - accuracy: 0.9308 - loss: 0.2619 - val_accuracy: 0.1154 - val_loss: 5.0860 - learning_rate: 0.0025
# Epoch 22/150
# 9/9 - 1s - 61ms/step - accuracy: 0.8308 - loss: 0.4741 - val_accuracy: 0.1154 - val_loss: 5.5974 - learning_rate: 0.0025
# Epoch 23/150
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 9/9 - 1s - 61ms/step - accuracy: 0.8462 - loss: 0.4286 - val_accuracy: 0.1154 - val_loss: 5.5362 - learning_rate: 0.0025
# Epoch 24/150
# 9/9 - 0s - 55ms/step - accuracy: 0.7385 - loss: 0.8191 - val_accuracy: 0.1231 - val_loss: 4.6670 - learning_rate: 0.0012
# Epoch 25/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9000 - loss: 0.3550 - val_accuracy: 0.1231 - val_loss: 4.4364 - learning_rate: 0.0012
# Epoch 26/150
# 9/9 - 1s - 61ms/step - accuracy: 0.8846 - loss: 0.3250 - val_accuracy: 0.1769 - val_loss: 3.9747 - learning_rate: 0.0012
# Epoch 27/150
# 9/9 - 0s - 54ms/step - accuracy: 0.8846 - loss: 0.4554 - val_accuracy: 0.1923 - val_loss: 3.4743 - learning_rate: 0.0012
# Epoch 28/150
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 9/9 - 1s - 75ms/step - accuracy: 0.9231 - loss: 0.2445 - val_accuracy: 0.1769 - val_loss: 3.8421 - learning_rate: 0.0012
# Epoch 29/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9077 - loss: 0.2657 - val_accuracy: 0.1769 - val_loss: 3.9294 - learning_rate: 6.2500e-04
# Epoch 30/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9538 - loss: 0.1602 - val_accuracy: 0.1846 - val_loss: 3.8088 - learning_rate: 6.2500e-04
# Epoch 31/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9154 - loss: 0.2845 - val_accuracy: 0.1923 - val_loss: 3.1950 - learning_rate: 6.2500e-04
# Epoch 32/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9154 - loss: 0.3077 - val_accuracy: 0.2615 - val_loss: 2.5659 - learning_rate: 6.2500e-04
# Epoch 33/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9385 - loss: 0.2171 - val_accuracy: 0.3692 - val_loss: 2.1755 - learning_rate: 6.2500e-04
# Epoch 34/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9769 - loss: 0.0940 - val_accuracy: 0.3923 - val_loss: 2.0000 - learning_rate: 6.2500e-04
# Epoch 35/150
# 9/9 - 0s - 56ms/step - accuracy: 0.9462 - loss: 0.1374 - val_accuracy: 0.4385 - val_loss: 1.8281 - learning_rate: 6.2500e-04
# Epoch 36/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9615 - loss: 0.1240 - val_accuracy: 0.4769 - val_loss: 1.6315 - learning_rate: 6.2500e-04
# Epoch 37/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9462 - loss: 0.1568 - val_accuracy: 0.4923 - val_loss: 1.5620 - learning_rate: 6.2500e-04
# Epoch 38/150
# 9/9 - 1s - 89ms/step - accuracy: 0.9308 - loss: 0.1663 - val_accuracy: 0.5154 - val_loss: 1.5289 - learning_rate: 6.2500e-04
# Epoch 39/150
# 9/9 - 1s - 142ms/step - accuracy: 0.9846 - loss: 0.0798 - val_accuracy: 0.5462 - val_loss: 1.4901 - learning_rate: 6.2500e-04
# Epoch 40/150
# 9/9 - 1s - 112ms/step - accuracy: 0.9462 - loss: 0.2039 - val_accuracy: 0.5692 - val_loss: 1.4876 - learning_rate: 6.2500e-04
# Epoch 41/150
# 9/9 - 1s - 70ms/step - accuracy: 0.9077 - loss: 0.2406 - val_accuracy: 0.5692 - val_loss: 1.4813 - learning_rate: 6.2500e-04
# Epoch 42/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9538 - loss: 0.1266 - val_accuracy: 0.6231 - val_loss: 1.3190 - learning_rate: 6.2500e-04
# Epoch 43/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9615 - loss: 0.0904 - val_accuracy: 0.6308 - val_loss: 1.1479 - learning_rate: 6.2500e-04
# Epoch 44/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9538 - loss: 0.1109 - val_accuracy: 0.6615 - val_loss: 1.1064 - learning_rate: 6.2500e-04
# Epoch 45/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9462 - loss: 0.1366 - val_accuracy: 0.6769 - val_loss: 1.0259 - learning_rate: 6.2500e-04
# Epoch 46/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9615 - loss: 0.1148 - val_accuracy: 0.7000 - val_loss: 0.9554 - learning_rate: 6.2500e-04
# Epoch 47/150
# 9/9 - 1s - 65ms/step - accuracy: 0.9308 - loss: 0.2062 - val_accuracy: 0.6692 - val_loss: 1.0303 - learning_rate: 6.2500e-04
# Epoch 48/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9308 - loss: 0.1939 - val_accuracy: 0.6308 - val_loss: 1.1240 - learning_rate: 6.2500e-04
# Epoch 49/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9308 - loss: 0.1761 - val_accuracy: 0.6538 - val_loss: 1.1947 - learning_rate: 6.2500e-04
# Epoch 50/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9538 - loss: 0.1587 - val_accuracy: 0.6615 - val_loss: 1.1382 - learning_rate: 6.2500e-04
# Epoch 51/150
# 9/9 - 0s - 53ms/step - accuracy: 0.9615 - loss: 0.2003 - val_accuracy: 0.7231 - val_loss: 0.9873 - learning_rate: 6.2500e-04
# Epoch 52/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9308 - loss: 0.1546 - val_accuracy: 0.7385 - val_loss: 0.8396 - learning_rate: 6.2500e-04
# Epoch 53/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9538 - loss: 0.1351 - val_accuracy: 0.7769 - val_loss: 0.6781 - learning_rate: 6.2500e-04
# Epoch 54/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9692 - loss: 0.1145 - val_accuracy: 0.7769 - val_loss: 0.6284 - learning_rate: 6.2500e-04
# Epoch 55/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9615 - loss: 0.1011 - val_accuracy: 0.8000 - val_loss: 0.5705 - learning_rate: 6.2500e-04
# Epoch 56/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9692 - loss: 0.1011 - val_accuracy: 0.8231 - val_loss: 0.5022 - learning_rate: 6.2500e-04
# Epoch 57/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9385 - loss: 0.1482 - val_accuracy: 0.7769 - val_loss: 0.7329 - learning_rate: 6.2500e-04
# Epoch 58/150
# 9/9 - 1s - 99ms/step - accuracy: 0.9769 - loss: 0.0948 - val_accuracy: 0.7385 - val_loss: 1.1746 - learning_rate: 6.2500e-04
# Epoch 59/150
# 9/9 - 1s - 132ms/step - accuracy: 0.9538 - loss: 0.1109 - val_accuracy: 0.7538 - val_loss: 1.1526 - learning_rate: 6.2500e-04
# Epoch 60/150
# 9/9 - 1s - 78ms/step - accuracy: 0.9692 - loss: 0.1627 - val_accuracy: 0.7769 - val_loss: 1.0415 - learning_rate: 6.2500e-04
# Epoch 61/150
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 9/9 - 0s - 54ms/step - accuracy: 0.9769 - loss: 0.1306 - val_accuracy: 0.7769 - val_loss: 0.9127 - learning_rate: 6.2500e-04
# Epoch 62/150
# 9/9 - 1s - 69ms/step - accuracy: 0.9923 - loss: 0.0652 - val_accuracy: 0.7769 - val_loss: 0.8586 - learning_rate: 3.1250e-04
# Epoch 63/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9538 - loss: 0.1192 - val_accuracy: 0.7846 - val_loss: 0.7825 - learning_rate: 3.1250e-04
# Epoch 64/150
# 9/9 - 0s - 53ms/step - accuracy: 0.9308 - loss: 0.2000 - val_accuracy: 0.8077 - val_loss: 0.6855 - learning_rate: 3.1250e-04
# Epoch 65/150
# 9/9 - 1s - 77ms/step - accuracy: 0.9462 - loss: 0.1638 - val_accuracy: 0.8231 - val_loss: 0.6041 - learning_rate: 3.1250e-04
# Epoch 66/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9538 - loss: 0.1406 - val_accuracy: 0.8308 - val_loss: 0.5617 - learning_rate: 3.1250e-04
# Epoch 67/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9615 - loss: 0.1418 - val_accuracy: 0.8769 - val_loss: 0.5100 - learning_rate: 3.1250e-04
# Epoch 68/150
# 9/9 - 1s - 73ms/step - accuracy: 0.9769 - loss: 0.0908 - val_accuracy: 0.8692 - val_loss: 0.4698 - learning_rate: 3.1250e-04
# Epoch 69/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9538 - loss: 0.1048 - val_accuracy: 0.8769 - val_loss: 0.4141 - learning_rate: 3.1250e-04
# Epoch 70/150
# 9/9 - 1s - 67ms/step - accuracy: 0.9846 - loss: 0.0804 - val_accuracy: 0.9000 - val_loss: 0.3896 - learning_rate: 3.1250e-04
# Epoch 71/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9769 - loss: 0.1016 - val_accuracy: 0.9077 - val_loss: 0.3662 - learning_rate: 3.1250e-04
# Epoch 72/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9769 - loss: 0.0993 - val_accuracy: 0.9154 - val_loss: 0.3496 - learning_rate: 3.1250e-04
# Epoch 73/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9615 - loss: 0.0836 - val_accuracy: 0.8923 - val_loss: 0.3824 - learning_rate: 3.1250e-04
# Epoch 74/150
# 9/9 - 1s - 72ms/step - accuracy: 0.9769 - loss: 0.1180 - val_accuracy: 0.8923 - val_loss: 0.4228 - learning_rate: 3.1250e-04
# Epoch 75/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9769 - loss: 0.0908 - val_accuracy: 0.8846 - val_loss: 0.4225 - learning_rate: 3.1250e-04
# Epoch 76/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9769 - loss: 0.0994 - val_accuracy: 0.8923 - val_loss: 0.4033 - learning_rate: 3.1250e-04
# Epoch 77/150
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 9/9 - 0s - 55ms/step - accuracy: 0.9769 - loss: 0.1157 - val_accuracy: 0.8846 - val_loss: 0.4212 - learning_rate: 3.1250e-04
# Epoch 78/150
# 9/9 - 1s - 81ms/step - accuracy: 0.9462 - loss: 0.2081 - val_accuracy: 0.8923 - val_loss: 0.4108 - learning_rate: 1.5625e-04
# Epoch 79/150
# 9/9 - 1s - 151ms/step - accuracy: 0.9308 - loss: 0.1378 - val_accuracy: 0.9000 - val_loss: 0.3936 - learning_rate: 1.5625e-04
# Epoch 80/150
# 9/9 - 1s - 109ms/step - accuracy: 0.9538 - loss: 0.1101 - val_accuracy: 0.9077 - val_loss: 0.3721 - learning_rate: 1.5625e-04
# Epoch 81/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9692 - loss: 0.0894 - val_accuracy: 0.9077 - val_loss: 0.3649 - learning_rate: 1.5625e-04
# Epoch 82/150
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 9/9 - 1s - 62ms/step - accuracy: 0.9846 - loss: 0.0488 - val_accuracy: 0.9077 - val_loss: 0.3530 - learning_rate: 1.5625e-04
# Epoch 83/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9923 - loss: 0.0759 - val_accuracy: 0.9000 - val_loss: 0.3442 - learning_rate: 7.8125e-05
# Epoch 84/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9769 - loss: 0.0769 - val_accuracy: 0.9077 - val_loss: 0.3331 - learning_rate: 7.8125e-05
# Epoch 85/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9385 - loss: 0.1747 - val_accuracy: 0.9231 - val_loss: 0.3227 - learning_rate: 7.8125e-05
# Epoch 86/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9846 - loss: 0.0765 - val_accuracy: 0.9231 - val_loss: 0.3205 - learning_rate: 7.8125e-05
# Epoch 87/150
# 9/9 - 0s - 53ms/step - accuracy: 0.9769 - loss: 0.0884 - val_accuracy: 0.9231 - val_loss: 0.3173 - learning_rate: 7.8125e-05
# Epoch 88/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9846 - loss: 0.0633 - val_accuracy: 0.9308 - val_loss: 0.3119 - learning_rate: 7.8125e-05
# Epoch 89/150
# 9/9 - 1s - 59ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 0.9308 - val_loss: 0.3111 - learning_rate: 7.8125e-05
# Epoch 90/150
# 9/9 - 1s - 63ms/step - accuracy: 0.9692 - loss: 0.1650 - val_accuracy: 0.9308 - val_loss: 0.3069 - learning_rate: 7.8125e-05
# Epoch 91/150
# 9/9 - 0s - 53ms/step - accuracy: 0.9769 - loss: 0.0743 - val_accuracy: 0.9308 - val_loss: 0.3030 - learning_rate: 7.8125e-05
# Epoch 92/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9769 - loss: 0.0841 - val_accuracy: 0.9308 - val_loss: 0.2995 - learning_rate: 7.8125e-05
# Epoch 93/150
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 9/9 - 1s - 70ms/step - accuracy: 0.9692 - loss: 0.0998 - val_accuracy: 0.9308 - val_loss: 0.2946 - learning_rate: 7.8125e-05
# Epoch 94/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9846 - loss: 0.0544 - val_accuracy: 0.9308 - val_loss: 0.2965 - learning_rate: 3.9062e-05
# Epoch 95/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9769 - loss: 0.0681 - val_accuracy: 0.9308 - val_loss: 0.2979 - learning_rate: 3.9062e-05
# Epoch 96/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9692 - loss: 0.0879 - val_accuracy: 0.9308 - val_loss: 0.2981 - learning_rate: 3.9062e-05
# Epoch 97/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9385 - loss: 0.1328 - val_accuracy: 0.9308 - val_loss: 0.2964 - learning_rate: 3.9062e-05
# Epoch 98/150
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 9/9 - 1s - 83ms/step - accuracy: 0.9846 - loss: 0.0584 - val_accuracy: 0.9308 - val_loss: 0.2958 - learning_rate: 3.9062e-05
# Epoch 99/150
# 9/9 - 1s - 163ms/step - accuracy: 0.9769 - loss: 0.0863 - val_accuracy: 0.9308 - val_loss: 0.2987 - learning_rate: 1.9531e-05
# Epoch 100/150
# 9/9 - 1s - 67ms/step - accuracy: 0.9692 - loss: 0.0663 - val_accuracy: 0.9308 - val_loss: 0.2983 - learning_rate: 1.9531e-05
# Epoch 101/150
# 9/9 - 1s - 64ms/step - accuracy: 0.9769 - loss: 0.0938 - val_accuracy: 0.9308 - val_loss: 0.2975 - learning_rate: 1.9531e-05
# Epoch 102/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9923 - loss: 0.0727 - val_accuracy: 0.9308 - val_loss: 0.2963 - learning_rate: 1.9531e-05
# Epoch 103/150
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 9.765624781721272e-06.
# 9/9 - 1s - 68ms/step - accuracy: 0.9692 - loss: 0.0834 - val_accuracy: 0.9308 - val_loss: 0.2970 - learning_rate: 1.9531e-05
# Epoch 104/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9769 - loss: 0.0679 - val_accuracy: 0.9308 - val_loss: 0.2976 - learning_rate: 9.7656e-06
# Epoch 105/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9846 - loss: 0.0735 - val_accuracy: 0.9308 - val_loss: 0.2984 - learning_rate: 9.7656e-06
# Epoch 106/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9769 - loss: 0.0744 - val_accuracy: 0.9308 - val_loss: 0.2995 - learning_rate: 9.7656e-06
# Epoch 107/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9615 - loss: 0.0939 - val_accuracy: 0.9308 - val_loss: 0.3001 - learning_rate: 9.7656e-06
# Epoch 108/150
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 4.882812390860636e-06.
# 9/9 - 0s - 54ms/step - accuracy: 0.9769 - loss: 0.0847 - val_accuracy: 0.9231 - val_loss: 0.2986 - learning_rate: 9.7656e-06
# Epoch 109/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9385 - loss: 0.1313 - val_accuracy: 0.9154 - val_loss: 0.3010 - learning_rate: 4.8828e-06
# Epoch 110/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9692 - loss: 0.0959 - val_accuracy: 0.9308 - val_loss: 0.2992 - learning_rate: 4.8828e-06
# Epoch 111/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9923 - loss: 0.0510 - val_accuracy: 0.9231 - val_loss: 0.2988 - learning_rate: 4.8828e-06
# Epoch 112/150
# 9/9 - 1s - 60ms/step - accuracy: 0.9615 - loss: 0.1180 - val_accuracy: 0.9308 - val_loss: 0.3013 - learning_rate: 4.8828e-06
# Epoch 113/150
#
# Epoch 113: ReduceLROnPlateau reducing learning rate to 2.441406195430318e-06.
# 9/9 - 1s - 57ms/step - accuracy: 1.0000 - loss: 0.0400 - val_accuracy: 0.9308 - val_loss: 0.3010 - learning_rate: 4.8828e-06
# Epoch 114/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9692 - loss: 0.0874 - val_accuracy: 0.9308 - val_loss: 0.2971 - learning_rate: 2.4414e-06
# Epoch 115/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9692 - loss: 0.0777 - val_accuracy: 0.9308 - val_loss: 0.2964 - learning_rate: 2.4414e-06
# Epoch 116/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9846 - loss: 0.0745 - val_accuracy: 0.9308 - val_loss: 0.2963 - learning_rate: 2.4414e-06
# Epoch 117/150
# 9/9 - 0s - 56ms/step - accuracy: 0.9538 - loss: 0.1079 - val_accuracy: 0.9308 - val_loss: 0.2974 - learning_rate: 2.4414e-06
# Epoch 118/150
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 1.220703097715159e-06.
# 9/9 - 0s - 53ms/step - accuracy: 0.9692 - loss: 0.1110 - val_accuracy: 0.9231 - val_loss: 0.2967 - learning_rate: 2.4414e-06
# Epoch 119/150
# 9/9 - 1s - 100ms/step - accuracy: 0.9846 - loss: 0.0593 - val_accuracy: 0.9308 - val_loss: 0.2974 - learning_rate: 1.2207e-06
# Epoch 120/150
# 9/9 - 1s - 131ms/step - accuracy: 0.9769 - loss: 0.0908 - val_accuracy: 0.9231 - val_loss: 0.2991 - learning_rate: 1.2207e-06
# Epoch 121/150
# 9/9 - 1s - 106ms/step - accuracy: 0.9846 - loss: 0.0663 - val_accuracy: 0.9231 - val_loss: 0.3011 - learning_rate: 1.2207e-06
# Epoch 122/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9538 - loss: 0.1099 - val_accuracy: 0.9231 - val_loss: 0.3007 - learning_rate: 1.2207e-06
# Epoch 123/150
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 1e-06.
# 9/9 - 1s - 74ms/step - accuracy: 0.9769 - loss: 0.1467 - val_accuracy: 0.9231 - val_loss: 0.3008 - learning_rate: 1.2207e-06
# Epoch 124/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9769 - loss: 0.0943 - val_accuracy: 0.9231 - val_loss: 0.3012 - learning_rate: 1.0000e-06
# Epoch 125/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9846 - loss: 0.0523 - val_accuracy: 0.9231 - val_loss: 0.3010 - learning_rate: 1.0000e-06
# Epoch 126/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9769 - loss: 0.0778 - val_accuracy: 0.9231 - val_loss: 0.3027 - learning_rate: 1.0000e-06
# Epoch 127/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9769 - loss: 0.0670 - val_accuracy: 0.9231 - val_loss: 0.3035 - learning_rate: 1.0000e-06
# Epoch 128/150
# 9/9 - 1s - 69ms/step - accuracy: 1.0000 - loss: 0.0439 - val_accuracy: 0.9231 - val_loss: 0.3017 - learning_rate: 1.0000e-06
# Epoch 129/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9923 - loss: 0.0409 - val_accuracy: 0.9231 - val_loss: 0.2989 - learning_rate: 1.0000e-06
# Epoch 130/150
# 9/9 - 1s - 62ms/step - accuracy: 0.9846 - loss: 0.0559 - val_accuracy: 0.9231 - val_loss: 0.3002 - learning_rate: 1.0000e-06
# Epoch 131/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9692 - loss: 0.0806 - val_accuracy: 0.9231 - val_loss: 0.3006 - learning_rate: 1.0000e-06
# Epoch 132/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9923 - loss: 0.0516 - val_accuracy: 0.9231 - val_loss: 0.3002 - learning_rate: 1.0000e-06
# Epoch 133/150
# 9/9 - 0s - 53ms/step - accuracy: 0.9462 - loss: 0.1151 - val_accuracy: 0.9231 - val_loss: 0.3012 - learning_rate: 1.0000e-06
# Epoch 134/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9769 - loss: 0.0655 - val_accuracy: 0.9231 - val_loss: 0.3022 - learning_rate: 1.0000e-06
# Epoch 135/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9923 - loss: 0.0346 - val_accuracy: 0.9231 - val_loss: 0.3027 - learning_rate: 1.0000e-06
# Epoch 136/150
# 9/9 - 1s - 57ms/step - accuracy: 0.9692 - loss: 0.0912 - val_accuracy: 0.9154 - val_loss: 0.3021 - learning_rate: 1.0000e-06
# Epoch 137/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9846 - loss: 0.0728 - val_accuracy: 0.9231 - val_loss: 0.3032 - learning_rate: 1.0000e-06
# Epoch 138/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9462 - loss: 0.0897 - val_accuracy: 0.9154 - val_loss: 0.3021 - learning_rate: 1.0000e-06
# Epoch 139/150
# 9/9 - 1s - 88ms/step - accuracy: 0.9692 - loss: 0.0979 - val_accuracy: 0.9231 - val_loss: 0.3017 - learning_rate: 1.0000e-06
# Epoch 140/150
# 9/9 - 1s - 155ms/step - accuracy: 0.9692 - loss: 0.1062 - val_accuracy: 0.9231 - val_loss: 0.3019 - learning_rate: 1.0000e-06
# Epoch 141/150
# 9/9 - 1s - 110ms/step - accuracy: 0.9846 - loss: 0.0645 - val_accuracy: 0.9231 - val_loss: 0.3004 - learning_rate: 1.0000e-06
# Epoch 142/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9846 - loss: 0.0769 - val_accuracy: 0.9154 - val_loss: 0.3007 - learning_rate: 1.0000e-06
# Epoch 143/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9769 - loss: 0.0660 - val_accuracy: 0.9154 - val_loss: 0.3000 - learning_rate: 1.0000e-06
# Epoch 144/150
# 9/9 - 1s - 56ms/step - accuracy: 0.9615 - loss: 0.0992 - val_accuracy: 0.9231 - val_loss: 0.2981 - learning_rate: 1.0000e-06
# Epoch 145/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9846 - loss: 0.0654 - val_accuracy: 0.9154 - val_loss: 0.2965 - learning_rate: 1.0000e-06
# Epoch 146/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9615 - loss: 0.1280 - val_accuracy: 0.9154 - val_loss: 0.2988 - learning_rate: 1.0000e-06
# Epoch 147/150
# 9/9 - 0s - 55ms/step - accuracy: 0.9769 - loss: 0.1052 - val_accuracy: 0.9231 - val_loss: 0.2969 - learning_rate: 1.0000e-06
# Epoch 148/150
# 9/9 - 0s - 54ms/step - accuracy: 0.9923 - loss: 0.0537 - val_accuracy: 0.9154 - val_loss: 0.2958 - learning_rate: 1.0000e-06
# Epoch 149/150
# 9/9 - 1s - 61ms/step - accuracy: 0.9846 - loss: 0.0611 - val_accuracy: 0.9231 - val_loss: 0.2948 - learning_rate: 1.0000e-06
# Epoch 150/150
# 9/9 - 1s - 59ms/step - accuracy: 0.9846 - loss: 0.0583 - val_accuracy: 0.9231 - val_loss: 0.2949 - learning_rate: 1.0000e-06
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Training set size: 130
# Layer sizes: Conv2D(32)->Conv2D(64)->Dense(128)->Dense(10)
# Accuracy for class 0: 100%
# Accuracy for class 1: 100%
# Accuracy for class 2: 100%
# Accuracy for class 3:  85%
# Accuracy for class 4:  92%
# Accuracy for class 5: 100%
# Accuracy for class 6:  85%
# Accuracy for class 7:  77%
# Accuracy for class 8:  92%
# Accuracy for class 9: 100%
# ----------
# Overall Test Accuracy: 93.1%
# Overall Training Accuracy: 100.0%
# Confusion Matrix:
# Class 0:    13     0     0     0     0     0     0     0     0     0
# Class 1:     0    13     0     0     0     0     0     0     0     0
# Class 2:     0     0    13     0     0     0     0     0     0     0
# Class 3:     0     0     2    11     0     0     0     0     0     0
# Class 4:     0     1     0     0    12     0     0     0     0     0
# Class 5:     0     0     0     0     0    13     0     0     0     0
# Class 6:     0     0     0     0     0     0    11     2     0     0
# Class 7:     0     1     0     0     0     0     1    10     1     0
# Class 8:     0     0     0     0     0     0     0     0    12     1
# Class 9:     0     0     0     0     0     0     0     0     0    13
